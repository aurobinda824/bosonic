# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from bosonic import GKPQubit, BosonicRegister, BosonicCircuit, execute

# %%
qubit = GKPQubit(params={"N":200})
breg = BosonicRegister([qubit])
bcirc = BosonicCircuit(breg)
qubit.plot_code_states()
# Out:
# e:\Project\SQH\bosonic\bosonic\codes\base.py:300: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
qubit.plot_code_states(qp_type="qfunc")

# %%
bcirc.plot(0) # plot initial state

# set up circuit
bcirc.reset()
bcirc.x(0)

# %%
results = execute(bcirc, "unitary_jax")
results.plot(bcirc,0)
